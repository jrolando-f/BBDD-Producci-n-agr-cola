# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
fao = pd.read_csv('/content/drive/MyDrive/Production_Crops_Livestock.csv', encoding = "ISO-8859-1")
fao.info()
# Out:
# <ipython-input-71-23d950cc8ac5>:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   fao = pd.read_csv('/content/drive/MyDrive/Production_Crops_Livestock.csv', encoding = "ISO-8859-1")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4127584 entries, 0 to 4127583
# Data columns (total 14 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Area Code        int64
#  1   Area Code (M49)  object
#  2   Area             object
#  3   Item Code        int64
#  4   Item Code (CPC)  object
#  5   Item             object
#  6   Element Code     int64
#  7   Element          object
#  8   Year Code        int64
#  9   Year             int64
#  10  Unit             object
#  11  Value            float64
#  12  Flag             object
#  13  Note             object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 440.9+ MB

# %%
fao.head(50)
# Out:
#     Area Code Area Code (M49)         Area  Item Code Item Code (CPC)  \
# 0           2            '004  Afghanistan        221          '01371
# 1           2            '004  Afghanistan        221          '01371
# 2           2            '004  Afghanistan        221          '01371
# 3           2            '004  Afghanistan        221          '01371
# 4           2            '004  Afghanistan        221          '01371
# 5           2            '004  Afghanistan        221          '01371
# 6           2            '004  Afghanistan        221          '01371
# 7           2            '004  Afghanistan        221          '01371
# 8           2            '004  Afghanistan        221          '01371
# 9           2            '004  Afghanistan        221          '01371
# 10          2            '004  Afghanistan        221          '01371
# 11          2            '004  Afghanistan        221          '01371
# ...

# %%
fao =fao.rename(columns={'Year': 'Code_year'})

# %%
fao =fao.drop('Item Code (CPC)', axis = 1)
fao =fao.drop('Area Code (M49)', axis = 1)
fao =fao.drop('Year Code', axis = 1)
fao =fao.drop('Note', axis = 1)

# %%
fao.to_csv('/content/produccion.csv', index=False)

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4127584 entries, 0 to 4127583
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Area Code     int64
#  1   Area          object
#  2   Item Code     int64
#  3   Item          object
#  4   Element Code  int64
#  5   Element       object
#  6   Code_year     int64
#  7   Unit          object
#  8   Value         float64
#  9   Flag          object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 314.9+ MB

# %%
elementos= fao

# %%
elementos =elementos.drop('Area', axis = 1)
elementos =elementos.drop('Area Code', axis = 1)
elementos =elementos.drop('Item Code', axis = 1)
elementos =elementos.drop('Item', axis = 1)
elementos =elementos.drop('Code_year', axis = 1)
elementos =elementos.drop('Unit', axis = 1)
elementos =elementos.drop('Value', axis = 1)
elementos =elementos.drop('Flag', axis = 1)

# %%
elementos.info()

# %%
elementos = elementos.drop_duplicates()

# %%
elementos

# %%
elementos.to_csv('/content/elementos.csv', index=False)

# %%
item = pd.read_csv('/content/item_code.csv', encoding = "ISO-8859-1")

# %%
item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Item Code    202 non-null    int64
#  1   Item         202 non-null    object
#  2   Description  195 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.9+ KB

# %% [markdown]
# item.to_csv('/content/item.csv', index=False)

# %%
reg_pais = pd.read_csv('/content/regiones.csv', encoding = "utf-8")
reg_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country Group Code  909 non-null    int64
#  1   Country Group       909 non-null    object
#  2   Group M49 Code      909 non-null    int64
#  3   Country Code        909 non-null    int64
#  4   Country             909 non-null    object
#  5   M49 Code            909 non-null    int64
#  6   ISO2 Code           905 non-null    object
#  7   ISO3 Code           909 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 56.9+ KB

# %%
reg_pais =reg_pais.drop('Group M49 Code', axis = 1)
reg_pais =reg_pais.drop('M49 Code', axis = 1)
reg_pais =reg_pais.drop('ISO2 Code', axis = 1)
reg_pais =reg_pais.drop('ISO3 Code', axis = 1)

# %%
reg_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country Group Code  909 non-null    int64
#  1   Country Group       909 non-null    object
#  2   Country Code        909 non-null    int64
#  3   Country             909 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.5+ KB

# %%
reg_pais =reg_pais.rename(columns={'Country Group Code': 'Region_Code'})
reg_pais =reg_pais.rename(columns={'Country Group': 'Region'})
reg_pais =reg_pais.rename(columns={'Country Code': 'Pais_Code'})
reg_pais =reg_pais.rename(columns={'Country': 'Pais'})

# %%
region = reg_pais

# %%
pais = reg_pais

# %%
pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region_Code  909 non-null    int64
#  1   Region       909 non-null    object
#  2   Pais_Code    909 non-null    int64
#  3   Pais         909 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.5+ KB

# %%
pais =pais.drop('Region_Code', axis = 1)
pais =pais.drop('Region', axis = 1)

# %%
pais.shape
# Out:
# (211, 2)

# %%
pais = pais.drop_duplicates()

# %%
pais.shape
# Out:
# (211, 2)

# %%
pais.to_csv('/content/pais.csv', index=False)

# %%
region =region.drop('Pais_Code', axis = 1)
region =region.drop('Pais', axis = 1)

# %%
region = region.drop_duplicates()

# %%
region
# Out:
#      Region_Code                                   Region
# 0           5100                                   Africa
# 57          5200                                 Americas
# 96          5300                                     Asia
# 148         5501                Australia and New Zealand
# 150         5206                                Caribbean
# 166         5204                          Central America
# 174         5301                             Central Asia
# 179         5101                           Eastern Africa
# 199         5302                             Eastern Asia
# 208         5401                           Eastern Europe
# 220         5400                                   Europe
# 265         5707                      European Union (27)
# 293         5802         Land Locked Developing Countries
# 325         5801                Least Developed Countries
# 372         5815        Low Income Food Deficit Countries
# ...

# %%
region.to_csv('/content/region.csv', index=False)

# %%
reg_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region_Code  909 non-null    int64
#  1   Region       909 non-null    object
#  2   Pais_Code    909 non-null    int64
#  3   Pais         909 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 28.5+ KB

# %%
reg_pais =reg_pais.drop('Region', axis = 1)
reg_pais =reg_pais.drop('Pais', axis = 1)

# %%
reg_pais
# Out:
#      Region_Code  Pais_Code
# 0           5100        107
# 1           5100        114
# 2           5100        122
# 3           5100        123
# 4           5100        124
# ..           ...        ...
# 904         5000         95
# 905         5000         96
# 906         5000         97
# 907         5000         98
# 908         5000         99
#
# [909 rows x 2 columns]

# %%
reg_pais.to_csv('/content/region_pais.csv', index=False)

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4127584 entries, 0 to 4127583
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Area Code     int64
#  1   Area          object
#  2   Item Code     int64
#  3   Item          object
#  4   Element Code  int64
#  5   Element       object
#  6   Code_year     int64
#  7   Unit          object
#  8   Value         float64
#  9   Flag          object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 314.9+ MB

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4127584 entries, 0 to 4127583
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Area Code     int64
#  1   Area          object
#  2   Item Code     int64
#  3   Item          object
#  4   Element Code  int64
#  5   Element       object
#  6   Code_year     int64
#  7   Unit          object
#  8   Value         float64
#  9   Flag          object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 314.9+ MB

# %%
elementos
# Out:
#          Element Code         Element
# 0                5312  Area harvested
# 1                5312  Area harvested
# 2                5312  Area harvested
# 3                5312  Area harvested
# 4                5312  Area harvested
# ...               ...             ...
# 4127579          5510      Production
# 4127580          5510      Production
# 4127581          5510      Production
# 4127582          5510      Production
# 4127583          5510      Production
#
# [4127584 rows x 2 columns]

# %%
prod_1 = fao[(fao['Element Code'] > 5115) ]

# %%
prod_area_cosechada = fao[(fao['Element Code'] ==  5312) ]

# %%
prod_area_cosechada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888731 entries, 0 to 4127459
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area Code     888731 non-null  int64
#  1   Area          888731 non-null  object
#  2   Item Code     888731 non-null  int64
#  3   Item          888731 non-null  object
#  4   Element Code  888731 non-null  int64
#  5   Element       888731 non-null  object
#  6   Code_year     888731 non-null  int64
#  7   Unit          888731 non-null  object
#  8   Value         888731 non-null  float64
#  9   Flag          888731 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 74.6+ MB

# %%
prod_rendimiento = fao[(fao['Element'] ==  "Yield") ]

# %%
prod_rendimiento["Element Code"].unique()
# Out:
# array([5419, 5410, 5413, 5420, 5422])

# %%
prod_rendimiento.shape
# Out:
# (922853, 10)

# %%
fao.to_csv('/content/fao_total.csv', index=False)

# %%
prod_rendimiento.to_csv('/content/prod_rendimiento_mundial.csv', index=False)

# %%
prod_area_cosechada.to_csv('/content/area_cosechada_mundial.csv', index=False)

# %%
reg_pais
# Out:
#      Region_Code  Pais_Code
# 0           5100        107
# 1           5100        114
# 2           5100        122
# 3           5100        123
# 4           5100        124
# ..           ...        ...
# 904         5000         95
# 905         5000         96
# 906         5000         97
# 907         5000         98
# 908         5000         99
#
# [909 rows x 2 columns]

# %%
reg_america = reg_pais[reg_pais['Region_Code'] == 5200]

# %%
reg_america
# Out:
#     Region_Code  Pais_Code
# 57         5200        109
# 58         5200         12
# 59         5200        135
# 60         5200        138
# 61         5200         14
# 62         5200        157
# 63         5200        166
# 64         5200        169
# 65         5200        170
# 66         5200        177
# 67         5200        188
# 68         5200        189
# 69         5200         19
# 70         5200        191
# 71         5200        207
# 72         5200         21
# 73         5200        220
# 74         5200         23
# 75         5200        231
# 76         5200        234
# 77         5200        236
# 78         5200         33
# 79         5200         40
# 80         5200         44
# 81         5200         48
# 82         5200         49
# 83         5200         55
# 84         5200         56
# 85         5200         58
# 86         5200         60
# 87         5200         69
# 88         5200          8
# 89         5200         86
# ...

# %%
reg_america.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 57 to 95
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region_Code  39 non-null     int64
#  1   Pais_Code    39 non-null     int64
# dtypes: int64(2)
# memory usage: 936.0 bytes

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4127584 entries, 0 to 4127583
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Area Code     int64
#  1   Area          object
#  2   Item Code     int64
#  3   Item          object
#  4   Element Code  int64
#  5   Element       object
#  6   Code_year     int64
#  7   Unit          object
#  8   Value         float64
#  9   Flag          object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 314.9+ MB

# %%
fao=fao.rename(columns={'Area Code': 'Pais_Code'})

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4127584 entries, 0 to 4127583
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Pais_Code     int64
#  1   Area          object
#  2   Item Code     int64
#  3   Item          object
#  4   Element Code  int64
#  5   Element       object
#  6   Code_year     int64
#  7   Unit          object
#  8   Value         float64
#  9   Flag          object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 314.9+ MB

# %%
America_todo = pd.merge(reg_america, fao, on="Pais_Code")

# %%
reg_africa= reg_pais[reg_pais['Region_Code'] == 5100]

# %%
africa = pd.merge(reg_africa, fao, on="Pais_Code")

# %%
africa
# Out:
#         Region_Code  Pais_Code Area Code (M49)           Area  Item Code  \
# 0              5100        107            '384  Côte d'Ivoire        221
# 1              5100        107            '384  Côte d'Ivoire        221
# 2              5100        107            '384  Côte d'Ivoire        221
# 3              5100        107            '384  Côte d'Ivoire        221
# 4              5100        107            '384  Côte d'Ivoire        221
# ...             ...        ...             ...            ...        ...
# 809177         5100         90            '324         Guinea       1735
# 809178         5100         90            '324         Guinea       1735
# 809179         5100         90            '324         Guinea       1735
# 809180         5100         90            '324         Guinea       1735
# 809181         5100         90            '324         Guinea       1735
#
#        Item Code (CPC)                Item  Element Code         Element  \
# ...

# %%
africa.to_csv('/content/drive/MyDrive/africa_todo.csv', index=False)
africa.to_csv('/content/africa_todo.csv', index=False)

# %%
America_todo.shape
# Out:
# (646315, 11)

# %%
America_todo
# Out:
#         Region_Code  Pais_Code      Area  Item Code                Item  \
# 0              5200        109   Jamaica       1107               Asses
# 1              5200        109   Jamaica       1107               Asses
# 2              5200        109   Jamaica       1107               Asses
# 3              5200        109   Jamaica       1107               Asses
# 4              5200        109   Jamaica       1107               Asses
# ...             ...        ...       ...        ...                 ...
# 646310         5200         95  Honduras       1735  Vegetables Primary
# 646311         5200         95  Honduras       1735  Vegetables Primary
# 646312         5200         95  Honduras       1735  Vegetables Primary
# 646313         5200         95  Honduras       1735  Vegetables Primary
# 646314         5200         95  Honduras       1735  Vegetables Primary
#
#         Element Code     Element  Code_year Unit      Value Flag
# ...

# %%
America_todo.to_csv('/content/America_todo.csv', index=False)

# %%
America_rendimiento = America_todo[(America_todo['Element'] ==  "Yield") ]

# %%
America_rendimiento.shape
# Out:
# (140666, 11)

# %%
America_rendimiento.to_csv('/content/America_rendimiento.csv', index=False)

# %%
America_todo['Element'].unique()
# Out:
# array(['Stocks', 'Area harvested', 'Yield', 'Production', 'Prod Popultn',
#        'Producing Animals/Slaughtered', 'Laying', 'Yield/Carcass Weight',
#        'Milk Animals'], dtype=object)

# %%
America_production= America_todo[(America_todo['Element'] ==  "Production") ]

# %%
America_production.to_csv('/content/America_produccion.csv', index=False)

# %%
America_production.shape
# Out:
# (251551, 11)

# %%
America_area_prod= America_todo[(America_todo['Element'] ==  "Area harvested") ]

# %%
America_area_prod.shape
# Out:
# (140886, 11)

# %%
America_area_prod.to_csv('/content/America_area_prod.csv', index=False)

# %%
fao.to_csv('/content/fao_mundial_todo.csv', index=False)

# %%
region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 0 to 698
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Region_Code  34 non-null     int64
#  1   Region       34 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 816.0+ bytes

# %%
region[(region['Region_Code']>5499)]
# Out:
#      Region_Code                                   Region
# 148         5501                Australia and New Zealand
# 265         5707                      European Union (27)
# 293         5802         Land Locked Developing Countries
# 325         5801                Least Developed Countries
# 372         5815        Low Income Food Deficit Countries
# 418         5502                                Melanesia
# 423         5503                               Micronesia
# 436         5817  Net Food Importing Developing Countries
# 536         5500                                  Oceania
# 554         5504                                Polynesia
# 561         5803           Small Island Developing States

# %%
africa = region[(region['Region_Code']<5200) ]
africa= africa[(africa['Region_Code']>5100 ) ]

# %%
africa
# Out:
#      Region_Code           Region
# 179         5101   Eastern Africa
# 427         5102    Middle Africa
# 516         5103  Northern Africa
# 628         5104  Southern Africa
# 656         5105   Western Africa

# %%
america = region[(region['Region_Code']<5300) ]
america= america[(america['Region_Code']>5200 ) ]

# %%
america
# Out:
#      Region_Code            Region
# 150         5206         Caribbean
# 166         5204   Central America
# 523         5203  Northern America
# 604         5207     South America

# %%
asia = region[(region['Region_Code']<5400) ]
asia= asia[(asia['Region_Code']>5300 ) ]

# %%
europa = region[(region['Region_Code']<5500) ]
europa= europa[(europa['Region_Code']>5400 ) ]

# %%
europa
# Out:
#      Region_Code           Region
# 208         5401   Eastern Europe
# 525         5402  Northern Europe
# 642         5403  Southern Europe
# 690         5404   Western Europe

# %%
oceania = region[(region['Region_Code']<5600) ]
oceania= oceania[(oceania['Region_Code']>5500 ) ]

# %%
oceania
# Out:
#      Region_Code                     Region
# 148         5501  Australia and New Zealand
# 418         5502                  Melanesia
# 423         5503                 Micronesia
# 554         5504                  Polynesia

# %%
sub_cont =pd.concat([africa, america,asia, europa, oceania])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-717b60b4e019> in <cell line: 1>()
# ----> 1 sub_cont =pd.concat([africa, america,asia, europa, oceania])
#
# NameError: name 'america' is not defined

# %%
sub_cont
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-5e5847a1e45e> in <cell line: 1>()
# ----> 1 sub_cont
#
# NameError: name 'sub_cont' is not defined

# %%
sub_cont.to_csv('/content/sub_regiones.csv', index=False)

# %%
sub_region_pais = reg_pais[(reg_pais['Region_Code']<5700) ]

# %%
sub_region_pais = sub_region_pais[(sub_region_pais['Region_Code']>5000) ]

# %%
sub_region_pais
sub_regiones = pd.merge(sub_region_pais, sub_cont, on="Region_Code")

# %%
sub_regiones
# Out:
#      Region_Code  Pais_Code          Region
# 0           5206        109       Caribbean
# 1           5206         12       Caribbean
# 2           5206        135       Caribbean
# 3           5206         14       Caribbean
# 4           5206        177       Caribbean
# ..           ...        ...             ...
# 233         5404        256  Western Europe
# 234         5404         68  Western Europe
# 235         5404         68  Western Europe
# 236         5404         79  Western Europe
# 237         5404         79  Western Europe
#
# [238 rows x 3 columns]

# %%
pais
# Out:
#      Pais_Code              Pais
# 0          107     Côte d'Ivoire
# 1          114             Kenya
# 2          122           Lesotho
# 3          123           Liberia
# 4          124             Libya
# ..         ...               ...
# 486        244             Samoa
# 543        160              Niue
# 545        218           Tokelau
# 550         47      Cook Islands
# 552         70  French Polynesia
#
# [211 rows x 2 columns]

# %%
region_pais  = pd.merge(pais, sub_regiones, on="Pais_Code")

# %%
region_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pais_Code    238 non-null    int64
#  1   Pais         238 non-null    object
#  2   Region_Code  238 non-null    int64
#  3   Region       238 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 7.6+ KB

# %%
sub_regiones_pais = sub_regiones.drop('Region', axis = 1)

# %%
sub_regiones_pais
# Out:
#      Region_Code  Pais_Code
# 0           5206        109
# 1           5206         12
# 2           5206        135
# 3           5206         14
# 4           5206        177
# ..           ...        ...
# 233         5404        256
# 234         5404         68
# 235         5404         68
# 236         5404         79
# 237         5404         79
#
# [238 rows x 2 columns]

# %%
region_pais.to_csv('/content/sub_region_pais.csv', index=False)

# %%
africa_todo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809182 entries, 0 to 809181
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Region_Code   809182 non-null  int64
#  1   Pais_Code     809182 non-null  int64
#  2   Area          809182 non-null  object
#  3   Item Code     809182 non-null  int64
#  4   Item          809182 non-null  object
#  5   Element Code  809182 non-null  int64
#  6   Element       809182 non-null  object
#  7   Code_year     809182 non-null  int64
#  8   Unit          809182 non-null  object
#  9   Value         809182 non-null  float64
#  10  Flag          809182 non-null  object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 67.9+ MB

# %%
oceania_todo
# Out:
#         Region_Code  Pais_Code Area Code (M49)       Area  Item Code  \
# 0              5500         10            '036  Australia        221
# 1              5500         10            '036  Australia        221
# 2              5500         10            '036  Australia        221
# 3              5500         10            '036  Australia        221
# 4              5500         10            '036  Australia        221
# ...             ...        ...             ...        ...        ...
# 160777         5500         83            '296   Kiribati       1735
# 160778         5500         83            '296   Kiribati       1735
# 160779         5500         83            '296   Kiribati       1735
# 160780         5500         83            '296   Kiribati       1735
# 160781         5500         83            '296   Kiribati       1735
#
#        Item Code (CPC)                Item  Element Code         Element  \
# ...

# %%
data = europa
data =data.drop('Region_Code', axis = 1)
data =data.drop('Area', axis = 1)
data =data.drop('Item', axis = 1)
#data.info()

# %%
data_1 = data[(data["Element"] == "Yield") & (data["Pais_Code"] < 5000)]
data_2 = data[(data["Element"] != "Yield") & (data["Pais_Code"] < 5000)]

# %%
data_1.to_csv('/content/drive/MyDrive/europa_yield_1.csv', index=False)
data_2.to_csv('/content/drive/MyDrive/europa_no_yield_1.csv', index=False)
